# %% [markdown]
# # Comparaison de la sélection de variables avec STABL (Random Forest, XGBoost, Lasso, ElasticNet)
#
# Ce notebook compare la sélection de variables et les performances de classification/régression entre STABL utilisant des modèles d’arbres (Random Forest, XGBoost) avec grid search, et STABL utilisant des modèles linéaires (Lasso, ElasticNet). Les résultats sont évalués par validation croisée, en termes de performances et de nombre de variables sélectionnées.

# %%
# Importer les bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression, Lasso, ElasticNet
from sklearn.metrics import accuracy_score, roc_auc_score, mean_squared_error
from stabl.stabl import Stabl
from stabl.adaptive import ALasso, ALogitLasso
from stabl.preprocessing import LowInfoFilter
# from stabl.visualization import plot_fdr_graph
from sklearn.feature_selection import VarianceThreshold
from sklearn.base import clone
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Charger et explorer les données
#
# Nous allons charger un jeu de données tabulaire (exemple : CyTOF.csv et outcome.csv), afficher ses dimensions, types de variables, et quelques statistiques descriptives.

# %%
# Charger les données (exemple : CyTOF.csv et outcome.csv)
features = pd.read_csv("data/COVID-19/Training/Proteomics.csv")
outcome = pd.read_csv("data/COVID-19/Training/Mild&ModVsSevere.csv")

print("Features shape:", features.shape)
print("Outcome shape:", outcome.shape)
print("Features columns:", features.columns.tolist()[:10], "...")
print("Outcome columns:", outcome.columns.tolist())

# Statistiques descriptives
print(features.describe())
print(outcome.describe())

# Afficher la distribution de la variable cible (exemple : model1b)
outcome["Mild&ModVsSevere"].value_counts().plot(kind="bar")
plt.title("Distribution de la variable cible")
plt.show()
# Out:
# Features shape: (68, 1464)
# Outcome shape: (68, 2)
# Features columns: ['sampleID', 'AARSD1', 'ABHD14B', 'ABL1', 'ACAA1', 'ACAN', 'ACE2', 'ACOX1', 'ACP5', 'ACP6'] ...
# Outcome columns: ['sampleID', 'Mild&ModVsSevere']
#           AARSD1    ABHD14B       ABL1      ACAA1       ACAN       ACE2  \
# count  68.000000  68.000000  68.000000  68.000000  68.000000  68.000000
# mean    5.855332   3.636771   6.350316   5.306296   4.008700   2.594200
# std     1.122131   1.182992   1.639027   1.701369   0.357109   0.782309
# min     3.085600   1.259200   2.484700   1.735500   3.120300   1.322200
# 25%     5.135525   2.712275   4.993575   4.035725   3.798150   2.003275
# 50%     5.880950   3.886500   6.311700   5.555200   4.012800   2.489750
# 75%     6.744550   4.626100   7.616100   6.483175   4.222925   2.996000
# max     7.848400   5.711400   9.761300   9.620800   4.938000   5.475900
#
#            ACOX1       ACP5       ACP6      ACTA2  ...      WNT9A       WWP2  \
# count  68.000000  68.000000  68.000000  68.000000  ...  68.000000  68.000000
# mean    1.335922   6.213716   7.551796   1.409282  ...   1.952715   7.545288
# std     0.805100   0.670407   0.888304   1.109587  ...   0.685774   1.010164
# min    -0.390600   4.725600   5.341100  -0.118900  ...   1.040100   5.058100
# 25%     0.756200   5.788350   7.023175   0.689200  ...   1.464450   6.685450
# 50%     1.332250   6.071250   7.493150   1.123850  ...   1.835250   7.668950
# 75%     1.876125   6.502275   8.039350   1.561600  ...   2.138575   8.337750
# max     3.032600   8.067800   9.542700   5.621400  ...   4.253900   9.086500
#
#             XCL1         XG    XPNPEP2      XRCC4       YES1     YTHDF3  \
# count  68.000000  68.000000  68.000000  68.000000  68.000000  68.000000
# mean    4.494316   4.343074   5.737684   1.292579   7.853472   4.645338
# std     0.809810   0.891059   1.187842   0.764568   1.699072   1.528207
# min     3.366700   2.814700   3.328100  -0.064300   3.146000   0.789500
# 25%     3.954175   3.851625   4.867325   0.704550   6.477950   3.234050
# 50%     4.326350   4.171700   5.874400   1.310550   8.110500   4.837750
# 75%     4.806725   4.524225   6.720200   1.780525   9.306900   5.791125
# max     7.567700   8.149700   7.873300   3.014700  10.523900   7.763400
#
#           ZBTB16     ZBTB17
# count  68.000000  68.000000
# mean    3.863501   2.917165
# std     1.760728   0.941815
# min     0.787600   1.357700
# 25%     2.336200   2.180650
# 50%     3.862000   2.800800
# 75%     5.140725   3.601500
# max     7.739100   5.383200
#
# [8 rows x 1463 columns]
#        Mild&ModVsSevere
# count         68.000000
# mean           0.367647
# std            0.485750
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max            1.000000

# %% [markdown]
# ## 2. Définir le préprocessing
#
# Pipeline de préprocessing : imputation, standardisation, filtrage faible variance, filtrage low info.

# %% [markdown]
# ## Configuration des pipelines STABL avec modèles d’arbres et linéaires
#
# Dans cette section, nous allons configurer plusieurs pipelines de sélection de variables et de modélisation :
# - **STABL + Random Forest** : sélection de variables avec STABL utilisant Random Forest comme estimateur, avec recherche de grille (grid search) pour optimiser les hyperparamètres, et validation croisée (cross-validation).
# - **STABL + XGBoost** : même principe, mais avec XGBoost comme estimateur.
# - **STABL + Lasso** : pipeline linéaire utilisant Lasso.
# - **STABL + ElasticNet** : pipeline linéaire utilisant ElasticNet.
#
# Pour chaque pipeline, nous appliquerons la sélection de variables, puis nous évaluerons les performances en cross-validation et le nombre de variables sélectionnées. Les résultats seront comparés à la fin du notebook.

# %% [markdown]
# ## Cross-validation, sauvegarde des résultats et visualisation
#
# Pour chaque modèle, nous allons :
# - Effectuer une cross-validation (stratifiée) sur le dataset.
# - Sauvegarder les courbes ROC et PR dans le dossier `Benchmarks results/` avec le nom du modèle et du dataset.
# - Sauvegarder les importances des variables sélectionnées et leur nombre.
# - Comparer les performances (AUC, accuracy, etc.) et le nombre de variables sélectionnées entre tous les modèles.
#
# Les résultats seront visualisés sous forme de tableaux et de graphes pour faciliter la comparaison.

# %% [markdown]
# ## Conclusion
#
# Ce notebook permet de comparer la sélection de variables et les performances de classification entre STABL (Random Forest, XGBoost, Lasso, ElasticNet) sur le dataset CyTOF. Les courbes ROC, PR, importances des variables et tableaux de résultats sont sauvegardés dans le dossier `Benchmarks results/` avec des noms explicites pour chaque modèle et dataset. Vous pouvez adapter ce pipeline à d'autres datasets en modifiant la section de chargement des données.

# %%
# Pipeline de préprocessing (à utiliser dans chaque pipeline)
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from stabl.preprocessing import LowInfoFilter

preprocessing = Pipeline([
    ("variance_threshold", VarianceThreshold(threshold=0)),
    ("low_info_filter", LowInfoFilter(max_nan_fraction=0.2)),
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
])

# %%
df = pd.read_csv("data/Biobank SSI/Proteomics.csv")
print(len(df["sampleID"].unique()))
# Out:
# 91

# %%
# ===============================
# 1. Imports et configuration générale
# ===============================
import os, re
import shutil
import numpy as np
import pandas as pd
from stabl import data
from stabl.multi_omic_pipelines import multi_omic_stabl_cv, multi_omic_stabl_cv_noe
from sklearn.model_selection import RepeatedStratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from stabl.stabl import Stabl
from stabl.adaptive import ALogitLasso
from sklearn.base import clone
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GroupShuffleSplit

np.random.seed(42)

# ===============================
# 2. Définition des splits de validation croisée
# ===============================
# Outer CV pour l'évaluation globale, inner CV pour la recherche d'hyperparamètres
#outer_cv = GroupShuffleSplit(n_splits=100, test_size=0.2, random_state=42)
outer_cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=5, random_state=42)
inner_cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=5, random_state=42)

# ===============================
# 3. Définition des estimateurs et grilles d'hyperparamètres
# ===============================
artificial_type = "knockoff"  # ou "random_permutation"

# Lasso
lasso = LogisticRegression(penalty="l1", class_weight="balanced", max_iter=int(1e6), solver="liblinear", random_state=42)
lasso_cv = GridSearchCV(lasso, param_grid={"C": np.logspace(-2, 2, 30)}, scoring="roc_auc", cv=inner_cv, n_jobs=-1)

#ElasticNet
en = LogisticRegression(penalty='elasticnet', solver='saga', class_weight='balanced', max_iter=int(1e4), random_state=42)
en_params = {"C": np.logspace(-2, 1, 10), "l1_ratio": [0.5, 0.7, 0.9]}
en_cv = GridSearchCV(en, param_grid=en_params, scoring="roc_auc", cv=inner_cv, n_jobs=-1)

# RandomForest
rf = RandomForestClassifier(random_state=42, max_features=0.2)
rf_grid = {"max_depth": [3, 5, 7, 9, 11]}
rf_cv = GridSearchCV(rf, scoring='roc_auc', param_grid=rf_grid, cv=inner_cv, n_jobs=-1)

# XGBoost
xgb = XGBClassifier(random_seed=42,n_jobs=-1)
xgb_grid = {"max_depth": [3, 6, 9], "reg_alpha": [0, 0.1, 0.5, 1]}
xgb_cv = GridSearchCV(xgb, scoring='roc_auc', param_grid=xgb_grid, cv=inner_cv, n_jobs=-1)

# CatBoost
# cb = CatBoostClassifier(random_state=42, iterations=500, verbose=False)
# cb_grid = {"depth": [3, 5, 7], "learning_rate": [0.01, 0.1, 0.2], "l2_leaf_reg": [1, 3, 5]}
# cb_cv = GridSearchCV(cb, scoring='roc_auc', param_grid=cb_grid, cv=inner_cv, n_jobs=-1)

# ===============================
# 4. Définition des estimateurs STABL
# ===============================
stabl_lasso = Stabl(
    base_estimator=lasso,
    n_bootstraps=100,
    artificial_type=artificial_type,
    artificial_proportion=1.,
    replace=False,
    fdr_threshold_range=np.arange(0.1, 1, 0.01),
    sample_fraction=0.5,
    random_state=42,
    lambda_grid={"C": np.linspace(0.01, 1, 10)},
    verbose=1
)

stabl_en = clone(stabl_lasso).set_params(
    base_estimator=en,
    n_bootstraps=100,
    lambda_grid=[{"C": np.logspace(-2, 1, 5), "l1_ratio": [0.5, 0.9]}],
    verbose=1
)

stabl_rf = clone(stabl_lasso).set_params(
    base_estimator=rf,
    n_bootstraps=100,
    lambda_grid=rf_grid,
    verbose=1
)

stabl_xgb = clone(stabl_lasso).set_params(
    base_estimator=xgb,
    #bootstrap_threshold="median",
    n_bootstraps=100,
    lambda_grid=[xgb_grid],
    verbose=1
)

# stabl_cb = clone(stabl_lasso).set_params(
#     base_estimator=cb,
#     n_bootstraps=100,
#     lambda_grid=[cb_grid],
#     verbose=1
# )

# ===============================
# 5. Dictionnaire des estimateurs pour le benchmark
# ===============================
estimators = {
    "lasso": lasso_cv,
#    "alasso": alasso_cv,
    "en": en_cv,
    "xgb": xgb_cv,
    "stabl_lasso": stabl_lasso,
#    "stabl_alasso": stabl_alasso,
    "stabl_en": stabl_en,
    "stabl_xgb": stabl_xgb,
}

models = [
#    "STABL Lasso",
    "STABL ALasso",
#    "STABL ElasticNet",
    "STABL XGBoost"
]

# juste après avoir construit ton dict estimators, ajoute :
estimators["en"]        = estimators["lasso"]        # placeholder vide
estimators["stabl_en"]  = estimators["stabl_lasso"]  # placeholder vide

estimators["alasso"]        = estimators["lasso"]        # placeholder vide
estimators["stabl_alasso"]  = estimators["stabl_lasso"]  # placeholder vide


# ===============================
# 6. Chargement des données
# ===============================
#X_train, X_valid, y_train, y_valid, ids, task_type = data.load_covid_19("data/COVID-19")
X_train, X_valid, y_train, y_valid, ids, task_type = data.load_ssi("data/Biobank SSI")
#X_train, X_valid, y_train, y_valid, ids, task_type = data.load_cfrna("data/CFRNA")

print("X_train shape:", X_train)
print("y_train shape:", y_train)

# Assainir les labels
y = y_train.astype(int)
vals = sorted(set(y.unique()))
print("Labels uniques:", vals)  # doit afficher [0, 1]
assert set(vals) <= {0, 1}

# 3) Early-fusion: concat CyTOF + Proteomics en un seul X
cyto = X_train["CyTOF"]
prot = X_train["Proteomics"].copy()

# (Option recommandé) Préfixer la protéomique pour éviter toute collision de noms :
#prot.columns = [f"PRO_{c}" for c in prot.columns]

# 4) Aligner les index sur l’intersection commune (y, cyto, prot)
common = y.index
for df in (cyto, prot):
    common = common.intersection(df.index)

y_train = y.loc[common]
X_train = {
    "CyTOF": cyto.loc[common],
    "Proteomics": prot.loc[common],
}
# # 2. Isoler le gros DataFrame CyTOF + DataFrame Proteomics
# cytof_full = X_train.pop("CyTOF")          # retire temporairement
# prot_df    = X_train.pop("Proteomics")     # retire temporairement

# # 3. Décomposer CyTOF en 3 sous-ensembles
# stim_map = {"unstim": "Unstim", "lps": "LPS", "il246": "IL246", "tnf": "TNF"}
# X_train  = {}                              # on reconstruit le dict final

# for short, nice in stim_map.items():
#     regex = re.compile(fr"(^|_)({short})(_|$)", flags=re.IGNORECASE)
#     cols  = [c for c in cytof_full.columns if regex.search(c)]
#     if not cols:
#         raise ValueError(f"Aucune colonne pour la stimulation « {short} »")
#     X_train[nice] = cytof_full[cols].copy()

# # 4. Ajouter Proteomics comme 4ᵉ entrée
# X_train["Proteomics"] = prot_df.copy()

# 5. Garder UNIQUEMENT les échantillons communs aux 4 DataFrames + y
# common = y_train.index.copy()
# for df in X_train.values():
#     common = common.intersection(df.index)
# if common.empty:
#     raise ValueError("Aucun échantillon commun entre omiques et labels.")

# for k in X_train:
#     X_train[k] = X_train[k].loc[common].copy()
# y_train = y_train.loc[common]

# print({k: df.shape for k, df in X_train.items()})  # aperçu des shapes

# 6. Groupes & CV
groups    = ids

# =========================================================================
# 5. Lancement du benchmark
# =========================================================================
save_path = "./Benchmarks results/SSI + XGB_test/KO"
if os.path.exists(save_path):
    shutil.rmtree(save_path, ignore_errors=True)

print("Run CV on Biobank SSI dataset")
print("IDs :", ids)

multi_omic_stabl_cv_noe(
    data_dict=X_train,
    y=y_train,
    outer_splitter=outer_cv,
    estimators=estimators,
    task_type=task_type,
    save_path=save_path,
    model_chosen="xgboost",
    importance_method="gain",
    outer_groups=groups,
    early_fusion=False,
    late_fusion=False,
    n_iter_lf=1000,
    models=models
)
# Out:
# X_train shape: {'CyTOF':             unstim_Baso_149Sm_CREB  unstim_Baso_150Nd_STAT5  \
# sampleID
# BBCR0002                  0.632924                 0.344065
# BBCR0003                  0.921823                 0.677804
# BBCR0005-1                0.570141                 0.342670
# BBCR0006                  0.784137                 0.542236
# BBCR0007                  0.915210                 0.472476
# ...                            ...                      ...
# BBCR0319                  0.620614                 0.641094
# BBCR0327                  0.354008                 0.456189
# BBCR0328                  0.475081                 0.480226
# BBCR0329                  0.286093                 0.425288
# BBCR0338                  0.528063                 0.505472
#
#             unstim_Baso_151Eu_p38  unstim_Baso_153Eu_STAT1  \
# sampleID
# BBCR0002                 0.028052                        0
# BBCR0003                 0.041205                        0
# BBCR0005-1               0.000000                        0
# BBCR0006                 0.013768                        0
# BBCR0007                 0.094055                        0
# ...                           ...                      ...
# BBCR0319                 0.000000                        0
# BBCR0327                 0.000000                        0
# BBCR0328                 0.000000                        0
# BBCR0329                 0.000000                        0
# BBCR0338                 0.000000                        0
#
#             unstim_Baso_154Sm_STAT3  unstim_Baso_155Gd_S6  \
# sampleID
# BBCR0002                   0.000000              1.143817
# BBCR0003                   0.000672              1.614141
# BBCR0005-1                 0.000000              1.118496
# BBCR0006                   0.000000              1.310737
# BBCR0007                   0.000000              1.367927
# ...                             ...                   ...
# BBCR0319                   0.008417              1.035282
# BBCR0327                   0.000000              0.785523
# BBCR0328                   0.000000              0.947210
# BBCR0329                   0.000000              0.886098
# BBCR0338                   0.000000              0.914023
#
#             unstim_Baso_159Tb_MAPKAPK2  unstim_Baso_164Dy_IkB  \
# sampleID
# BBCR0002                      0.150393               0.801140
# BBCR0003                      0.138246               0.966064
# BBCR0005-1                    0.203688               0.635467
# BBCR0006                      0.178254               1.036648
# BBCR0007                      0.266016               1.033455
# ...                                ...                    ...
# BBCR0319                      0.099922               1.166167
# BBCR0327                      0.128279               0.582159
# BBCR0328                      0.053376               0.612781
# BBCR0329                      0.038477               0.579093
# BBCR0338                      0.158816               0.624084
#
#             unstim_Baso_166Er_NFkB  unstim_Baso_167Er_ERK  ...  \
# sampleID                                                   ...
# BBCR0002                  0.681250               0.031901  ...
# BBCR0003                  0.562168               0.000000  ...
# BBCR0005-1                0.779029               0.000000  ...
# BBCR0006                  0.592654               0.000000  ...
# BBCR0007                  1.175967               0.008453  ...
# ...                            ...                    ...  ...
# BBCR0319                  0.484620               0.005688  ...
# BBCR0327                  0.640126               0.000000  ...
# BBCR0328                  0.609292               0.000000  ...
# BBCR0329                  0.654153               0.000000  ...
# BBCR0338                  0.701997               0.000000  ...
#
#             LPS_Tregmem_159Tb_MAPKAPK2  LPS_Tregmem_164Dy_IkB  \
# sampleID
# BBCR0002                     -0.050975               0.010408
# BBCR0003                      0.002157              -0.012116
# BBCR0005-1                    0.017213               0.048801
# BBCR0006                     -0.090383              -0.096165
# BBCR0007                     -0.213809              -0.128997
# ...                                ...                    ...
# BBCR0319                      0.031934               0.062273
# BBCR0327                      0.108351               0.094072
# BBCR0328                      0.121002               0.062163
# BBCR0329                      0.138020               0.114254
# BBCR0338                      0.000441               0.237021
#
#             LPS_Tregmem_166Er_NFkB  LPS_Tregmem_167Er_ERK  \
# sampleID
# BBCR0002                 -0.188661              -0.071906
# BBCR0003                 -0.187465              -0.062873
# BBCR0005-1                0.025910              -0.068341
# BBCR0006                 -0.246929              -0.091677
# BBCR0007                 -0.551719              -0.010010
# ...                            ...                    ...
# BBCR0319                  0.054746               0.101254
# BBCR0327                  0.049948               0.147305
# BBCR0328                  0.127136               0.107103
# BBCR0329                  0.201522               0.145437
# BBCR0338                 -0.105007               0.083466
#
#             LPS_Tregnaive_149Sm_CREB  LPS_Tregnaive_155Gd_S6  \
# sampleID
# BBCR0002                   -0.028483                0.168303
# BBCR0003                    0.083203                0.244954
# BBCR0005-1                 -0.021477                0.139624
# BBCR0006                   -0.067768                0.215417
# BBCR0007                   -0.105540                0.129753
# ...                              ...                     ...
# BBCR0319                    0.036597               -0.025125
# BBCR0327                   -0.032644                0.024621
# BBCR0328                   -0.196909                0.035138
# BBCR0329                    0.042867                0.050046
# BBCR0338                    0.064841                0.118266
#
#             LPS_Tregnaive_159Tb_MAPKAPK2  LPS_Tregnaive_164Dy_IkB  \
# sampleID
# BBCR0002                       -0.075982                -0.056675
# BBCR0003                       -0.009757                 0.003002
# BBCR0005-1                      0.087390                -0.095174
# BBCR0006                       -0.014259                -0.103032
# BBCR0007                       -0.087284                -0.132580
# ...                                  ...                      ...
# BBCR0319                       -0.013118                -0.052701
# BBCR0327                        0.138122                 0.174059
# BBCR0328                        0.062949                -0.257096
# BBCR0329                       -0.374254                 0.289533
# BBCR0338                        0.168713                 0.381361
#
#             LPS_Tregnaive_166Er_NFkB  LPS_Tregnaive_167Er_ERK
# sampleID
# BBCR0002                   -0.306158                -0.082648
# BBCR0003                   -0.194244                -0.021312
# BBCR0005-1                 -0.101958                -0.125327
# BBCR0006                   -0.320417                -0.176559
# BBCR0007                   -0.397854                -0.118012
# ...                              ...                      ...
# BBCR0319                   -0.041246                -0.004774
# BBCR0327                    0.227327                 0.121366
# BBCR0328                    0.034493                 0.210423
# BBCR0329                    0.399971                 0.030833
# BBCR0338                   -0.112122                -0.061345
#
# [93 rows x 1125 columns], 'Proteomics':               CRYBB2       VDR     DUSP4     WNT10A      NCF2      FOXM1  \
# sampleID
# BBCR0002    9.064473  9.330021  9.173927  10.092493  8.922733   9.054197
# BBCR0003    8.997462  8.968955  9.019313   9.625161  8.554589  10.103681
# BBCR0005-1  8.798958  9.045760  9.082149   9.173927  8.708739  10.130828
# BBCR0006    9.059615  9.082947  8.965784   9.157347  8.638074  10.093814
# BBCR0007    9.015415  9.192539  9.159114   9.930146  8.748528   9.304694
# ...              ...       ...       ...        ...       ...        ...
# BBCR0319    8.957973  9.042207  8.952450  10.148095  8.822093  10.878894
# BBCR0327    8.946614  8.986695  9.002815   8.797662  8.758223   9.702519
# BBCR0328    8.892695  8.878358  9.204816   9.381759  9.019313   9.703038
# BBCR0329    9.401946  8.964630  9.164656   8.314697  9.069584   9.270062
# BBCR0338    8.871905  9.080018  8.998308   9.872213  8.825913  10.659372
#
#                 PLCG2      BAG3        CBS     CRYAA  ...       SAT1  \
# sampleID                                              ...
# BBCR0002     9.351602  9.658211  10.116084  8.406418  ...   9.571184
# BBCR0003     9.720073  9.207990  10.296687  8.260684  ...   9.349171
# BBCR0005-1  10.337510  9.306973  11.088788  8.272397  ...   9.398957
# BBCR0006     9.590587  9.225207  10.913488  8.365885  ...  10.880731
# BBCR0007     9.559377  9.361066  10.161384  8.378512  ...   9.455738
# ...               ...       ...        ...       ...  ...        ...
# BBCR0319     9.859535  9.375039   9.791814  8.378945  ...   9.245077
# BBCR0327     9.506208  9.474112  10.112048  8.495056  ...   9.568336
# BBCR0328     9.660531  9.251009  10.197462  8.376777  ...   9.393390
# BBCR0329     9.900867  9.077884  10.718362  9.229780  ...   9.672779
# BBCR0338     9.927334  9.309476  10.337064  8.306062  ...   9.379595
#
#                 NFKB1     CDKN2B      RAP2A     XRCC4    ARID1A      EGLN1  \
# sampleID
# BBCR0002    11.314243  10.127736   9.873905  8.623150  9.615262  10.399064
# BBCR0003    13.429106   9.698531   9.763378  8.799929  9.465362  10.176298
# BBCR0005-1  11.946797   9.765866   9.213590  8.695576  9.364572  10.103157
# BBCR0006    12.387048   9.765369   9.416375  8.299208  9.400026  10.672779
# BBCR0007    10.836603   9.932067   9.604183  8.647458  9.683872  10.606035
# ...               ...        ...        ...       ...       ...        ...
# BBCR0319    12.162549  12.852198  10.326654  8.859845  9.653383  10.219047
# BBCR0327    12.195249   9.869594  10.093153  8.532161  9.309249  10.241745
# BBCR0328    12.025589   9.661600   9.325530  8.823049  9.521600  10.221225
# BBCR0329    10.939726   9.529431  10.651141  8.245077  8.802839   9.854401
# BBCR0338    12.265644   9.652128  10.740877  8.783326  9.721783  10.083479
#
#               TOPBP1   SLC22A16       IRF6
# sampleID
# BBCR0002    8.828454  12.143543  11.980247
# BBCR0003    8.386294  12.561980  11.355186
# BBCR0005-1  8.153805  12.418353  11.495555
# BBCR0006    8.353147  13.040101  10.722295
# BBCR0007    8.338514  12.503577  10.450696
# ...              ...        ...        ...
# BBCR0319    8.480992  12.737564  11.348175
# BBCR0327    8.262095  12.109341  10.355241
# BBCR0328    8.422485  12.816804  11.021813
# BBCR0329    8.199182  12.587332  10.603812
# BBCR0338    8.350055  12.469184  12.135036
#
# [91 rows x 721 columns]}
# y_train shape: sampleID
# BBCR0002      1
# BBCR0003      0
# BBCR0005-1    0
# BBCR0006      0
# BBCR0007      0
#              ..
# BBCR0319      1
# BBCR0327      0
# BBCR0328      0
# BBCR0329      0
# BBCR0338      1
# Name: model1b, Length: 93, dtype: int64
# Labels uniques: [0, 1]
# Run CV on Biobank SSI dataset
# IDs : None
# 72 train samples, 19 test samples:   0%|          | 0/25 [00:00<?, ?it/s]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:07<00:00,  1.31it/s]
# STABL ALasso finished on CyTOF (72 samples); 6 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:19<00:00,  1.65s/it]
# STABL XGBoost finished on CyTOF (72 samples); 2 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.71it/s]
# STABL ALasso finished on Proteomics (72 samples); 11 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:17<00:00,  1.48s/it]
# STABL XGBoost finished on Proteomics (72 samples); 1 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 17 features selected for STABL ALasso
# This fold: 3 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:   4%|▍         | 1/25 [00:56<22:41, 56.74s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:00<00:00, 10.38it/s]
# STABL ALasso finished on CyTOF (73 samples); 7 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:21<00:00,  1.76s/it]
# STABL XGBoost finished on CyTOF (73 samples); 2 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.69it/s]
# STABL ALasso finished on Proteomics (73 samples); 20 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:20<00:00,  1.71s/it]
# STABL XGBoost finished on Proteomics (73 samples); 3 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 27 features selected for STABL ALasso
# This fold: 5 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:   8%|▊         | 2/25 [01:43<19:23, 50.60s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.69it/s]
# STABL ALasso finished on CyTOF (73 samples); 8 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:24<00:00,  2.08s/it]
# STABL XGBoost finished on CyTOF (73 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.82it/s]
# STABL ALasso finished on Proteomics (73 samples); 13 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.93s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 21 features selected for STABL ALasso
# This fold: 0 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  12%|█▏        | 3/25 [02:35<18:55, 51.63s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.52it/s]
# STABL ALasso finished on CyTOF (73 samples); 4 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.19s/it]
# STABL XGBoost finished on CyTOF (73 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.70it/s]
# STABL ALasso finished on Proteomics (73 samples); 4 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:22<00:00,  1.86s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 8 features selected for STABL ALasso
# This fold: 0 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  16%|█▌        | 4/25 [03:29<18:21, 52.43s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.22it/s]
# STABL ALasso finished on CyTOF (73 samples); 6 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.98s/it]
# STABL XGBoost finished on CyTOF (73 samples); 5 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:00<00:00, 10.43it/s]
# STABL ALasso finished on Proteomics (73 samples); 13 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:21<00:00,  1.79s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 19 features selected for STABL ALasso
# This fold: 5 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 72 train samples, 19 test samples:  20%|██        | 5/25 [04:19<17:09, 51.49s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.12it/s]
# STABL ALasso finished on CyTOF (72 samples); 7 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:24<00:00,  2.00s/it]
# STABL XGBoost finished on CyTOF (72 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.55it/s]
# STABL ALasso finished on Proteomics (72 samples); 19 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:22<00:00,  1.84s/it]
# STABL XGBoost finished on Proteomics (72 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 26 features selected for STABL ALasso
# This fold: 0 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  24%|██▍       | 6/25 [05:10<16:17, 51.46s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.86it/s]
# STABL ALasso finished on CyTOF (73 samples); 12 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:25<00:00,  2.13s/it]
# STABL XGBoost finished on CyTOF (73 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.57it/s]
# STABL ALasso finished on Proteomics (73 samples); 37 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:21<00:00,  1.82s/it]
# STABL XGBoost finished on Proteomics (73 samples); 2 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 49 features selected for STABL ALasso
# This fold: 2 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  28%|██▊       | 7/25 [06:03<15:32, 51.78s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.85it/s]
# STABL ALasso finished on CyTOF (73 samples); 6 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.17s/it]
# STABL XGBoost finished on CyTOF (73 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.47it/s]
# STABL ALasso finished on Proteomics (73 samples); 13 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:22<00:00,  1.91s/it]
# STABL XGBoost finished on Proteomics (73 samples); 1 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 19 features selected for STABL ALasso
# This fold: 1 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  32%|███▏      | 8/25 [06:56<14:50, 52.38s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.37it/s]
# STABL ALasso finished on CyTOF (73 samples); 7 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.20s/it]
# STABL XGBoost finished on CyTOF (73 samples); 3 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.80it/s]
# STABL ALasso finished on Proteomics (73 samples); 20 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.95s/it]
# STABL XGBoost finished on Proteomics (73 samples); 2 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 27 features selected for STABL ALasso
# This fold: 5 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  36%|███▌      | 9/25 [07:54<14:23, 53.94s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.54it/s]
# STABL ALasso finished on CyTOF (73 samples); 3 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:28<00:00,  2.38s/it]
# STABL XGBoost finished on CyTOF (73 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.82it/s]
# STABL ALasso finished on Proteomics (73 samples); 17 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:24<00:00,  2.06s/it]
# STABL XGBoost finished on Proteomics (73 samples); 2 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 20 features selected for STABL ALasso
# This fold: 2 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 72 train samples, 19 test samples:  40%|████      | 10/25 [08:52<13:50, 55.36s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  6.62it/s]
# STABL ALasso finished on CyTOF (72 samples); 4 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:30<00:00,  2.52s/it]
# STABL XGBoost finished on CyTOF (72 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.23it/s]
# STABL ALasso finished on Proteomics (72 samples); 24 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.95s/it]
# STABL XGBoost finished on Proteomics (72 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 28 features selected for STABL ALasso
# This fold: 0 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  44%|████▍     | 11/25 [09:53<13:16, 56.86s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.29it/s]
# STABL ALasso finished on CyTOF (73 samples); 9 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.25s/it]
# STABL XGBoost finished on CyTOF (73 samples); 1 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.88it/s]
# STABL ALasso finished on Proteomics (73 samples); 8 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.98s/it]
# STABL XGBoost finished on Proteomics (73 samples); 3 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 17 features selected for STABL ALasso
# This fold: 4 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  48%|████▊     | 12/25 [10:48<12:14, 56.49s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.84it/s]
# STABL ALasso finished on CyTOF (73 samples); 4 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.24s/it]
# STABL XGBoost finished on CyTOF (73 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.65it/s]
# STABL ALasso finished on Proteomics (73 samples); 9 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.95s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 13 features selected for STABL ALasso
# This fold: 0 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  52%|█████▏    | 13/25 [11:43<11:12, 56.08s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.89it/s]
# STABL ALasso finished on CyTOF (73 samples); 2 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.20s/it]
# STABL XGBoost finished on CyTOF (73 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.93it/s]
# STABL ALasso finished on Proteomics (73 samples); 17 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.94s/it]
# STABL XGBoost finished on Proteomics (73 samples); 2 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 19 features selected for STABL ALasso
# This fold: 2 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  56%|█████▌    | 14/25 [12:40<10:19, 56.35s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.69it/s]
# STABL ALasso finished on CyTOF (73 samples); 4 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.18s/it]
# STABL XGBoost finished on CyTOF (73 samples); 3 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.88it/s]
# STABL ALasso finished on Proteomics (73 samples); 7 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.96s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 11 features selected for STABL ALasso
# This fold: 3 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 72 train samples, 19 test samples:  60%|██████    | 15/25 [13:35<09:18, 55.83s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.99it/s]
# STABL ALasso finished on CyTOF (72 samples); 11 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:27<00:00,  2.28s/it]
# STABL XGBoost finished on CyTOF (72 samples); 1 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.45it/s]
# STABL ALasso finished on Proteomics (72 samples); 8 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:24<00:00,  2.00s/it]
# STABL XGBoost finished on Proteomics (72 samples); 3 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 19 features selected for STABL ALasso
# This fold: 4 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  64%|██████▍   | 16/25 [14:31<08:23, 55.99s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.71it/s]
# STABL ALasso finished on CyTOF (73 samples); 21 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:27<00:00,  2.25s/it]
# STABL XGBoost finished on CyTOF (73 samples); 3 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.97it/s]
# STABL ALasso finished on Proteomics (73 samples); 27 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:25<00:00,  2.09s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 48 features selected for STABL ALasso
# This fold: 3 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  68%|██████▊   | 17/25 [15:28<07:30, 56.35s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.26it/s]
# STABL ALasso finished on CyTOF (73 samples); 22 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:28<00:00,  2.34s/it]
# STABL XGBoost finished on CyTOF (73 samples); 1 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.89it/s]
# STABL ALasso finished on Proteomics (73 samples); 14 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:25<00:00,  2.12s/it]
# STABL XGBoost finished on Proteomics (73 samples); 1 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 36 features selected for STABL ALasso
# This fold: 2 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  72%|███████▏  | 18/25 [16:27<06:39, 57.05s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  6.96it/s]
# STABL ALasso finished on CyTOF (73 samples); 5 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:27<00:00,  2.28s/it]
# STABL XGBoost finished on CyTOF (73 samples); 2 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.99it/s]
# STABL ALasso finished on Proteomics (73 samples); 14 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.99s/it]
# STABL XGBoost finished on Proteomics (73 samples); 1 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 19 features selected for STABL ALasso
# This fold: 3 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  76%|███████▌  | 19/25 [17:24<05:41, 56.96s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.36it/s]
# STABL ALasso finished on CyTOF (73 samples); 4 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:27<00:00,  2.30s/it]
# STABL XGBoost finished on CyTOF (73 samples); 2 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.94it/s]
# STABL ALasso finished on Proteomics (73 samples); 8 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:23<00:00,  1.97s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 12 features selected for STABL ALasso
# This fold: 2 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 72 train samples, 19 test samples:  80%|████████  | 20/25 [18:20<04:43, 56.72s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.59it/s]
# STABL ALasso finished on CyTOF (72 samples); 3 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:27<00:00,  2.26s/it]
# STABL XGBoost finished on CyTOF (72 samples); 0 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.95it/s]
# STABL ALasso finished on Proteomics (72 samples); 27 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:24<00:00,  2.03s/it]
# STABL XGBoost finished on Proteomics (72 samples); 1 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 30 features selected for STABL ALasso
# This fold: 1 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  84%|████████▍ | 21/25 [19:17<03:46, 56.64s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.62it/s]
# STABL ALasso finished on CyTOF (73 samples); 3 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:28<00:00,  2.39s/it]
# STABL XGBoost finished on CyTOF (73 samples); 1 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.21it/s]
# STABL ALasso finished on Proteomics (73 samples); 13 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:25<00:00,  2.17s/it]
# STABL XGBoost finished on Proteomics (73 samples); 1 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 16 features selected for STABL ALasso
# This fold: 2 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  88%|████████▊ | 22/25 [20:18<02:53, 57.97s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.85it/s]
# STABL ALasso finished on CyTOF (73 samples); 9 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:27<00:00,  2.32s/it]
# STABL XGBoost finished on CyTOF (73 samples); 4 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.64it/s]
# STABL ALasso finished on Proteomics (73 samples); 14 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:24<00:00,  2.04s/it]
# STABL XGBoost finished on Proteomics (73 samples); 3 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 23 features selected for STABL ALasso
# This fold: 7 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  92%|█████████▏| 23/25 [21:15<01:55, 57.82s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.47it/s]
# STABL ALasso finished on CyTOF (73 samples); 9 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.18s/it]
# STABL XGBoost finished on CyTOF (73 samples); 2 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  9.38it/s]
# STABL ALasso finished on Proteomics (73 samples); 7 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:22<00:00,  1.91s/it]
# STABL XGBoost finished on Proteomics (73 samples); 2 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 16 features selected for STABL ALasso
# This fold: 4 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples:  96%|█████████▌| 24/25 [22:11<00:57, 57.35s/it]Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  7.90it/s]
# STABL ALasso finished on CyTOF (73 samples); 4 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:26<00:00,  2.24s/it]
# STABL XGBoost finished on CyTOF (73 samples); 2 features selected
# Fitting of STABL ALasso
# Stabl progress: 100%|██████████| 10/10 [00:01<00:00,  8.40it/s]
# STABL ALasso finished on Proteomics (73 samples); 18 features selected
# Fitting of STABL XGBoost
# Stabl progress: 100%|██████████| 12/12 [00:25<00:00,  2.09s/it]
# STABL XGBoost finished on Proteomics (73 samples); 0 features selected
# ~~~~~~~~~~~~~~~~~~~
# This fold: 22 features selected for STABL ALasso
# This fold: 2 features selected for STABL XGBoost
# ~~~~~~~~~~~~~~~~~~~
#
# 73 train samples, 18 test samples: 100%|██████████| 25/25 [23:08<00:00, 55.56s/it]
# Saving results...
# STABL ALasso sampleID
# BBCR0002      0.035374
# BBCR0003      0.061681
# BBCR0005-1    0.004340
# BBCR0006      0.017272
# BBCR0007      0.009390
#                 ...
# BBCR0319      0.035850
# BBCR0327      0.003284
# BBCR0328      0.004154
# BBCR0329      0.302069
# BBCR0338      0.167790
# Length: 91, dtype: float32
# STABL XGBoost sampleID
# BBCR0002      0.006207
# BBCR0003      0.020681
# BBCR0005-1    0.010045
# BBCR0006      0.001379
# BBCR0007      0.022416
#                 ...
# BBCR0319      0.021057
# BBCR0327      0.019613
# BBCR0328      0.037079
# BBCR0329      0.182680
# BBCR0338      0.018442
# Length: 91, dtype: float64
# {'STABL ALasso': sampleID
#  BBCR0002      0.035374
#  BBCR0003      0.061681
#  BBCR0005-1    0.004340
#  BBCR0006      0.017272
#  BBCR0007      0.009390
#                  ...
#  BBCR0319      0.035850
#  BBCR0327      0.003284
#  BBCR0328      0.004154
#  BBCR0329      0.302069
#  BBCR0338      0.167790
#  Length: 91, dtype: float32,
#  'STABL XGBoost': sampleID
#  BBCR0002      0.006207
#  BBCR0003      0.020681
#  BBCR0005-1    0.010045
#  BBCR0006      0.001379
#  BBCR0007      0.022416
#                  ...
#  BBCR0319      0.021057
#  BBCR0327      0.019613
#  BBCR0328      0.037079
#  BBCR0329      0.182680
#  BBCR0338      0.018442
#  Length: 91, dtype: float64}

# %%
X_train, X_valid, y_train, y_valid, ids, task_type = data.load_ssi("data/Biobank SSI")


X=pd.concat(X_train.values(), axis=1)

y=pd.concat([y_train], axis=1)

print("X shape:", X.shape)
print("y shape:", y.shape)


indices_X = set(X.index)
indices_y = set(y.index)

print("Index dans X_train mais pas dans y_train :", sorted(indices_X - indices_y))
print("Index dans y_train mais pas dans X_train :", sorted(indices_y - indices_X))


common = set(y.index)

common = pd.Index(sorted(common))
print("Index communs :", len(common))

xgb =XGBClassifier(
    n_estimators=1000,
    max_depth=3,
    learning_rate=0.1,
    random_state=42,
    importance_type="gain"
)

xgb.fit(X,y)

# Afficher les importances des caractéristiques
importances = xgb.feature_importances_
feature_names = X.columns
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)
print(importance_df.head(10))
# Out:
# X shape: (93, 1846)
# y shape: (93, 1)
# Index dans X_train mais pas dans y_train : []
# Index dans y_train mais pas dans X_train : []
# Index communs : 93
#                         Feature  Importance
# 1344                      PSMB9    0.056320
# 1484                     EIF4G1    0.042948
# 1327                     ASRGL1    0.034495
# 37    unstim_CD4Tcm_154Sm_STAT3    0.033057
# 351    unstim_Treg_168Er_pSTAT6    0.032746
# 1725                      IFNL3    0.026527
# 73      unstim_CD4Trm_164Dy_IkB    0.026478
# 1387                      CNTN3    0.025869
# 1649                        RAN    0.025824
# 1555                       CCL3    0.025051
